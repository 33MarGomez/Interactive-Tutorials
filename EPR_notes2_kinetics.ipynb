# %% [markdown]
# <a href="https://colab.research.google.com/github/33MarGomez/Interactive-Tutorials/blob/main/EPR_notes2_kinetics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Notes in EPR: Kinetics
# (Part 2 of 2)
#
# By: Marco Gomez
#
# Updated version (section added)- May 18, 2026

# %% [markdown]
# ##Motivation
# These sections all have the same thing in common- they use conclusions from the hamiltonian with either $\tau_2$ in the case of kinetics, or $2\pi sin\theta$ in the case of randomly oriented solids, to create different fields at the molecule. More specifically, the most powerful field at every molecule $S_z$, say, is spread across environments or salt domains in angle against the macroscopic field axis which is registered as $B_0$ as the relevant processes are either activated or deactivated. A special little bonus is in the Pulses section, an emerging field, where use of microwave frequencies can selectively excite phenomena. The main problem with this technique is the comparison between scanning time and relaxation time at this part of the spectrum, which is why it is significantly more developed in NMR. Still, it does contain a useful model in transition probabilities and resonance that can be brought forward as a field effect, the Rabi Problem.

# %% [markdown]
# ##Empirical Kinetic Relationships
# A good starting point is the parameterization of line broadening to the total nuclear spin of equivalent nuclei. Note the assumption their magnetogyric ratios are positive cancel out first by the square in $\gamma_i$ then by multiplication in $\gamma_{i,j}$ where any negative $M_{I(j)}$ would interact with positive gamma the same way as negative gamma and positive $M_{I(J)}$.
# $$\Gamma = \alpha + \sum_{i}\beta_{i}({}^tM_{I(i)})+\sum_{i}\gamma_{i}({}^tM_{I(i)}^2)+\sum_{i<j}\gamma_{i,j}({}^tM_{I(i)}{}^tM_{I(j)})$$
#
# A general empirical relationship is collected by Weil & Bolton for mole fractions $f$ of splitting constants $a$ following interconversion between species a and b [1],[2]. The line is only ever wider than the average of the two exchanging species.
# $$\Gamma = \bar{\Gamma} + f_af_b\tau|\bar{\gamma}|(a_a-a_b)^2M_I^2$$
# $$\tau = \frac{\tau_a + \tau_b}{\tau_a \tau_b}$$
# $$\bar{\Gamma}=f_a\Gamma_{0a}+f_b\Gamma_{0b}$$
# $$\bar{\gamma}=f_a\gamma_{a}+f_b\gamma_{b}$$
# At very low temperatures, phonon-assisted non-radiative processes dominate. They use a high-temperature approximation in nearly all experimental conditions, and differ by the spin number of the system.
# $$\tau_{1,S=1/2} \propto B^{-4}T^{-1}$$
# $$\tau_{1,S>1/2} \propto B^{-2}T^{-1}$$
#
# [1]. Weil, J. A.; Bolton, J. R. Relaxation Times, Linewidths and Spin-Kinetic Phenomena *Electron Paramagnetic Resonance: Elementary Theory and Practical Applications*, 2nd Ed.; Wiley, 2007; pp 301 - 356
#
# [2]. Fraenkel, G. K. *J. Phys. Chem* **1967** *71*(1), 139 - 171. [DOI: 10.1021/j100860a019](https://doi.org/10.1021/j100860a019)

# %% [markdown]
# ##Susceptibilities and Power
# The Steady-state solutions to the Bloch equation in a rotating frame with a perpendicular oscillating field, and steady applied field are used in magnetic susceptibilities. $\omega$ is the oscillation of the applied field with x and y components.
# $$M_{x\phi}=-M_z^0\frac{\gamma_eB_1(\omega_B-\omega)\tau_2^2}{1+(\omega_B-\omega)^2\tau_2^2+\gamma_e^2B_1^2\tau_1\tau_2}$$
# $$M_{y\phi}=+M_z^0\frac{\gamma_eB_1\tau_2}{1+(\omega_B-\omega)^2\tau_2^2+\gamma_e^2B_1^2\tau_1\tau_2}$$
# $$M_{z}=+M_z^0\frac{1+(\omega_B-\omega)^2\tau_2^2}{1+(\omega_B-\omega)^2\tau_2^2+\gamma_e^2B_1^2\tau_1\tau_2}$$
# $$\omega_B = -\gamma_e B$$
#
# $$\chi_0=\frac{\kappa\mu_0N_Vg^2\mu_{B(e)}^2}{4k_bT}$$
#
# $$M_Z^0 = \frac{\chi^0 B}{\kappa \mu_0}$$
#
# $M_Z^0$ can also be predicted in terms of steady state population transitions per unit time, $W$, though these quantities might be difficult to extract in practice.
# $$M_Z^0 = \frac{1}{2}g\mu_{B(e)}\Delta N_{ss}/V$$
# $$\Delta N_{ss} = N\frac{A_{ul}+W_{\downarrow}-W_{\uparrow}}{A_{ul}+2B_{ul}\rho_{\nu}+W_{\downarrow}+W_{\uparrow}}$$
#
# $$B_{ul} = B_{lu}$$
# Susceptibilities correspond to x and y magnetizations reduced over the applied field and multiplied by permeability of the medium, with y related to x by the $\tau_2$ constant.
# $$\chi'=\chi_0\frac{\omega_B(\omega_B-\omega)\tau_2^2}{1+(\omega_B-\omega)^2\tau_2^2+\gamma_e^2B_1^2\tau_1\tau_2}$$
#
# $$\chi'=\chi_0\frac{\omega_B\tau_2}{1+(\omega_B-\omega)^2\tau_2^2+\gamma_e^2B_1^2\tau_1\tau_2}$$
#
# $$\chi''=\chi'(\omega_B-\omega)\tau_2$$
#
# $$\chi' = +\frac{\kappa\mu_0 M_{x\phi}}{B_1}$$
# $$\chi'' = -\frac{\kappa\mu_0 M_{y\phi}}{B_1}$$
#
# The power absorbed by the sample is dictated by susceptability. If $\gamma_e^2B_1^2\tau_1\tau_2 << 1$, that term can be neglected and the power absorption is proportional to $B_1^2$. V is the volume of the sample. The Lorentzian has a half width at its half height predicted by function $\Gamma$.
# $$P(\omega)=\frac{\omega\chi''B_1^2}{\mu_0}V$$
# $$P=\frac{\pi}{\mu_0}\frac{B_1^2}{(1+\gamma_e^2B_1^2\tau_1\tau_2)^{1/2}}\omega\omega_B\chi_0Y(\omega-\omega_B)$$
#
# $$\Gamma = \frac{1}{\gamma_e\tau_2}(1+\gamma_e^2B_1^2\tau_1\tau_2)^{1/2}$$
# $$Y(\omega-\omega_B) = Y_{max} \frac{\Gamma^2}{\Gamma^2+(\omega-\omega_{B})^2}$$
# $$Y_{max} = Y\big|_{\omega=\omega_B}=\frac{1}{\pi\Gamma}$$
#
# Defining reaction rates, the complex transverse magnetization is compared to first-rate kinetics. $\epsilon$ is for species a or b as the starting expressions are identical, the stand-in for mole fraction is the magnetization vector such that flux creating species uses rate constant labelled of the opposite species and its magnetization vector. The coefficients $\alpha$ are complex values, with the imaginary portion of the equation dictating intensity of transition.
#
# $$M_{+\phi}=M_{x\phi} + iM_{y\phi}$$
# $$\frac{dM_{+\phi}}{dt}+(\tau_2^{-1}-i(\omega_B-\omega))M_{+\phi}=i\gamma_eB_1M_z$$
# $$\frac{dM_{+\phi,\epsilon}}{dt}+(\tau_{2,\epsilon}^{-1}-i(\omega_{B,\epsilon}-\omega))M_{+\phi,\epsilon}=i\gamma_eB_1M_{z,\epsilon}+k_{-1 \epsilon}M_{+\phi,\ne \epsilon}-k_{1,\epsilon}M_{+\phi,\epsilon}$$
#
# $$\frac{dM_{+\phi,\epsilon}}{dt} = \frac{dM_{z,\epsilon}}{dt}=0$$
#
# $$M_{z,\epsilon} = f_{\epsilon}\gamma_{\epsilon}M_z^0/\bar{\gamma}$$
#
# $$M_{+\phi}= iB_1M_z^0\frac{f_a\gamma_a(\alpha_b + k_a + k_b) + f_b\gamma_b(\alpha_a + k_a + k_b)}{(\alpha_a+k_a)(\alpha_b+k_b)-k_ak_b}$$
#
# $$M_{+\phi}= iB_1M_z^0\frac{\bar{\gamma}+\tau(f_a\gamma_a\alpha_b+f_b\gamma_b\alpha_a)}{\tau\alpha_a\alpha_b + f_a\alpha_a + f_b\alpha_b}$$
#
# $$\alpha_{\epsilon} = \tau_{2,\epsilon}^{-1}-i(\omega_{B,\epsilon}-\omega)$$
#
# The more compact version involves dividing reciprocal $\tau^{-1} = \tau_a^{-1} + \tau_b^{-1}$ equals $\tau^{-1} = \frac{\tau_b + \tau_a}{\tau_a\tau_b}$ from the equation. The denominator then creates mole fraction $f_{\epsilon} = \tau_{\epsilon}/(\tau_{\epsilon} + \tau_{\ne \epsilon})$ via $k_{\epsilon} = \tau_{\epsilon}^{-1}$. Or apply $\tau/\tau$ with these relationships. At intermediate dynamics, the field shifts. The coalescence point expression is given. In slow dynamics, one of the magnetization vectors is approximated to zero. In fast dynamics, all $\tau$ containing terms are neglected.
# $$(B_b - B_a)_t = ((B_b - B_a)_0^2-2(\bar{\gamma}\tau)^{-2})^{1/2}$$
# $$\tau=\frac{2\sqrt{2}}{|\bar{\gamma}|(B_b-B_a)}$$
# In cases of single electron transfer, a two-species relaxation time is used of radical concentration $[R]$. In the line-width equation, a 2/3 multiplier, 1/3 of encounters produce no reaction, causes the two-species $|2\tau|^{-2}$ cancellation.
#
# $$\Gamma = \Gamma_0 + |3\gamma_e\tau|^{-1}$$
#
# $$k_{(2)}=\frac{1}{2\tau[R]}$$
#
# The imaginary part of the magnetization vectors, $\tau$ dependent, may assemble an Arhennius plot, $\tau^{-1}$ versus $T^{-1}$ as directly corresponding to conversion rate. Relative areas of the absorption curves adequately represent mole fractions [1].
#
# [1].  Weil, J. A.; Bolton, J. R. Relaxation Times, Linewidths and Spin-Kinetic Phenomena *Electron Paramagnetic Resonance: Elementary Theory and Practical Applications*, 2nd Ed.; Wiley, 2007; pp 301 - 356

# %% [markdown]
# ##Pulses
# Noted by Weil and Bolton to be an emerging field as of 2006 [3]. Of value, its approach to the Rabi problem for upper and lower state populations - specifically, the probability of the system being found in upper and lower states. The pre-sine factor is equal to 1 at the resonance frequency, with $\nu_1$ the frequency of the driving field oscillating at frequency $\nu$. Thus, when the variance in the excitation field matches the fundamental frequency of the electron transition, the system has sinusoidal behaviour, $\omega_B = \gamma_eB$
#
# $$P=\bigg(\frac{\nu_1}{(\nu_1^2+(\nu-\nu_B)^2)^{1/2}}\bigg)^2sin^2(\pi(\nu_1^2+(\nu-\nu_B)^2)^{1/2}(t-t_0))$$
#
# $$\nu_B = g\mu_{B(e)}B/h$$
#
# Relaxation times may leave several critical experiments inaccessible [3].
#
# [3].  Weil, J. A.; Bolton, J. R. Non-continuous Excitation of Spins *Electron Paramagnetic Resonance: Elementary Theory and Practical Applications*, 2nd Ed.; Wiley, 2007; pp 357 - 384

# %% [markdown]
# ##Powders
# The broadest description for the evaluation strategy for randomly oriented crystal domains, powders and salts, is to randomly orient the z axis relative to the field. These quantities are integrated over a rotation matrix of angle $\vartheta$ about the y-axis and $\phi$ [4].
# $$\hat{r} = \begin{bmatrix}
# cos \phi \ cos \vartheta & -sin\phi & cos \phi \ sin \vartheta \\
# sin \phi \ cos \vartheta & cos\phi & sin \phi \ sin \vartheta \\
# -sin \vartheta & 0 & cos \vartheta
# \end{bmatrix}$$
# This is also a fractional surface area element, dividing the considered radius by the total radius available in the sphere, representing a probability. While $R^2$ is used in the first expression to communicate the fraction, $r^2$ is the appropriate element of integration that cancels in the jacobian. This permits usage of a unit sphere, which matches our intuition about the role of a radius vector in probability of alignment with the field. Angle $\theta$ is now being used as the angle between the field in z-direction and the z-axis of the particular molecule. The $4\pi$ of the whole surface area element arises from integrating the hidden x-y plane, its measurement doesn't change in the orientation of the field, which creates an explicit angular dependency that sums to $2 \pi$. This expression is correct.
#
# $$\Omega = \frac{4\pi r^2}{R^2}$$
#
# $$d\Omega = \frac{2 \pi r^2 sin \theta}{r^2} = 2\pi sin\theta$$
#
# $$P(\theta) d(\theta) = \frac{d\Omega}{4\pi} = \frac{1}{2} sin\theta d\theta \propto P(B)dB$$
#
# $$P(B) = \frac{sin\theta d\theta}{dB} = \frac{sin\theta}{dB/ d \theta }$$
#
# A constant of proportionality between $P(B)$ and $P(\theta)$ is found to be 2, and that cancels with the one-half factor arising from dividing by $4\pi$. The decision to place $d\theta / dB$ at the bottom is the simpler method of differentiating the field expression with respect to angular arguments it already contains, as part of its field cosines and other such eigenvalue expressions (see lesson 1 on non-quantized eigenfunctions). A substitution integration in terms of $f(\theta)d\theta \propto dB$ would have created this form anyhow. This is seen explictly in such a field differentiation in the anisotropic g-expression.
#
# $$B = \frac{h\nu}{g \mu_{B(e)}}$$
#
# $$g =( n^T \cdot g \cdot g^T \cdot n)^{1/2}$$
#
# The general uniaxial form is a special case of the diagonal matrix solution.
#
# $$cos\varphi = sin\varphi$$
# $$\varphi = \frac{\pi}{4}$$
# $$g^2 = \begin{bmatrix} c_{\perp} & c_{\perp} & c_{\parallel} \end{bmatrix} \cdot \begin{bmatrix} g_{\perp} & 0 & 0 \\
# 0 & g_{\perp} & 0 \\
# 0 & 0 & g_{\parallel}
# \end{bmatrix} \cdot
# \begin{bmatrix} c_{\perp} \\ c_{\perp} \\ c_{\parallel} \end{bmatrix} $$
#
# $$c_{\perp} = sin\varphi cos\theta = cos \varphi cos \theta = \frac{1}{\sqrt{2}}cos\theta$$
#
# The most basic uniaxial case is the averaging of the formula between the principal axis and field B. The first form uses $c_{\perp}$ squaring, canceling the $1/2$ factor with two perpendicular forms. The second form then results from pythegorean identity, $1 = cos^2 \theta + sin^2 \theta$. This form is useful if rhombic symmetry is inadequately resolved against resolution, requiring simplification. In practice, the absolute value function is practiced as identical results arising from half the unit sphere (crystal) orientations, only $\theta = \pi /2$ integration is required
#
# $$B = (g_{\perp}^2sin^2 \theta + g_{\parallel}^2sin^2 \theta)^{-1/2} \frac{h\nu}{\mu_{B(e)}}$$
#
# $$B = (g_{\perp} - (g_{\perp}^2 - g_{\parallel}^2)cos^2 \theta)^{-1/2} \frac{h\nu}{\mu_{B(e)}}$$
#
# $$\frac{dB}{d\theta} = -\frac{1}{2}\big ( g_{\perp}^2 - (g_{\perp}^2-g_{\parallel}^2)cos\theta \big )^{-3/2} (-2|(g_{\perp}^2-g_{\parallel}^2)cos\theta|) sin \theta \frac{h\nu}{\mu_{B(e)}}$$
#
# $$P(B,\theta) = \bigg ( \frac{h\nu}{\mu_{B(e)}} \bigg)^2 \frac{1}{B^3|(g_{\perp}^2-g_{\parallel}^2)cos\theta|}$$
#
# The equation rises monotonically to infinity as $B$ approaches $B_{\perp}$ because at $cos 0 = 1$, the field dependency on $g_{\parallel}$ causes a probability of $P(B) \propto B^{-1}$ that only increases as cosine approaches zero. For rhombic symmetries with $S = 1/2$ a convenient relationship is provided by Kliava assuming zero line-width [5] [6].
#
# $$L(\theta, \phi) = \kappa(T)\frac{\nu_0^2\mu_{B(e)}B_1^2}{8g^3}(g_x^2g_y^2(1-n_z^2) + g_x^2g_z^2(1-n_y^2)+g_y^2g_z^2(1-n_x^2))$$
#
# Each equation has a weighted linewidth function, F, modifying the intensity function L. The integration variable covers all resonant fields $B_{res}$ and euler angles $\Omega_1$ between the macroscopic sample axes and the applied and static fields. $\Delta_{B}$ is a species-specific linewidth and so may reference the previous work on kinetic effects. $L(R,\Omega_2)$ can also be used, where random vector R of the spin hamiltonian parameters, is subject to euler angle set $\Omega_2$ between the local magnetic axis and the macroscopic sample axes.
#
# $$Q = \int_{0}^{+\infty} L(B_{res},\Omega_1)F(B-B_{res},\Delta_B(B_{res},\Omega_{1})) \ dV(B_{res},\Omega_1)$$
#
# For hyperfine effects, the intensity function for an sp hybrid orbital in case of $S = I = 1/2$ is as follows. It uses the equivalence between the principal axis of the hybrid angle with the z-axis, $\theta_p$, as being equivalent to the overall random orientation angle $\theta$. The $\alpha_p$ quantity integrates over the angle off the principal axis for an expectation value of the electronic wavefunction.
#
# $$L(\theta) = \frac{sin\theta}{dB_{hf}/d\theta}=-\frac{g((1-\zeta)^2 + 3(2 + \zeta)\zeta \ cos^2\theta)^{1/2}} {3g_eM_I(2+\zeta)\zeta \ cos\theta}$$
#
# $$\zeta = \delta A / A_0$$
#
# $$\delta A = \frac{1}{4\pi}\mu_0g\mu_{B(e)}g_n\mu_{B(n)} \biggl \langle \frac{3cos^2 (\alpha_p) - 1}{3r^3} \biggl \rangle$$
#
# $$A_0 = tr(A)/3$$
#
# $$A(\theta_p)=\big((A_0-\delta A)^2+3(2A_0+\delta A)\delta A*cos^2 \theta_p\big)^{1/2} = B_{hf}(2g_n\mu_{B(n)})=(B_\perp\ ^2 + B_\parallel\ ^2)^{1/2}(2g_n\mu_{B(n)})$$
#
# In triplet states, perturbation theory is used when zeeman energy is sufficiently large to dipolar splitting $|D| = (3/2)|D_z|$. The result provided here is for the higher field transition, which is used with shift. A prior step uses the same differentiation with respect to field as has been previously used. $\theta$ is the angle with the field of the molecular z axis and $\phi$ the azimuthal angle of the molecular z axis with the field.
#
# $$P(B_{h})\propto \frac{g\mu_{B(e)}}{6D|cos\theta|}$$
#
# $$\bar{B}-B_{l}= \frac{1}{2g\mu_{B(e)}}(D(3cos^2\theta - 1) + 3Esin^2\theta cos^2 \phi)^{1/2}$$
#
# $$\bar{B} = \frac{B_h + B_l}{2}$$
#
# [4]. Quintes, T.; Weber, S.; Richert, S. Teacups, a Python Package for the Simulation of Time-Resolved EPR Spectra of Spin-Polarized Multi-Spin Systems. *The Journal of Physical Chemistry A* **2025**, *129*(14), 3375 - 3388. DOI: [10.1021/acs.jpca.5c01512](https://pubs.acs.org/doi/10.1021/acs.jpca.5c01512)
#
# [5].  J. Kliava, EPR Spectroscopy of Disordered Solids, Zinatne, Riga, Latvia 1988 (in Russian).
#
# [6]. Weil, J. A.; Bolton, J. R. Non-continuous Excitation of Spins Electron Paramagnetic Resonance: Elementary Theory and Practical Applications, 2nd Ed.; Wiley, 2007; pp 85 - 117

# %% [markdown]
# ##References
#
# All cells have citations in their footnotes as a redundancy. You may delete this cell if you wish.
#
# [1]. Weil, J. A.; Bolton, J. R. Relaxation Times, Linewidths and Spin-Kinetic Phenomena *Electron Paramagnetic Resonance: Elementary Theory and Practical Applications*, 2nd Ed.; Wiley, 2007; pp 301 - 356
#
# [2]. Fraenkel, G. K. *J. Phys. Chem* **1967** *71*(1), 139 - 171. [DOI: 10.1021/j100860a019](https://doi.org/10.1021/j100860a019)
#
# [3]. Weil, J. A.; Bolton, J. R. Non-continuous Excitation of Spins Electron Paramagnetic Resonance: Elementary Theory and Practical Applications, 2nd Ed.; Wiley, 2007; pp 357 - 384
#
# [4]. Quintes, T.; Weber, S.; Richert, S. Teacups, a Python Package for the Simulation of Time-Resolved EPR Spectra of Spin-Polarized Multi-Spin Systems. *The Journal of Physical Chemistry A* **2025**, *129*(14), 3375 - 3388. DOI: [10.1021/acs.jpca.5c01512](https://pubs.acs.org/doi/10.1021/acs.jpca.5c01512)
#
# [5].  J. Kliava, EPR Spectroscopy of Disordered Solids, Zinatne, Riga, Latvia 1988 (in Russian).
#
# [6]. Weil, J. A.; Bolton, J. R. Non-continuous Excitation of Spins Electron Paramagnetic Resonance: Elementary Theory and Practical Applications, 2nd Ed.; Wiley, 2007; pp 85 - 117
